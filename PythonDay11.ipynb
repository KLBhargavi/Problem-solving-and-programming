# %% [markdown]
# # PROBLEM SOLVING AND PROGRAMMING
# ## Koduganti Lakshmi Bhargavi
# ## Day no. 19
# ## Date 18th May 2019

# %% [markdown]
# ## Problem 1
# ### Problem statement
# Plotting 2D graphs using Matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

plt.plot([1,2,3,4],[1,2,3,4])
plt.xlabel('time')
plt.ylabel('distance')
plt.show()

# %% [markdown]
# ## Problem 2
# ### Problem statement
# Plotting 2D graphs using Matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

plt.plot([1,2,3,4],[1,4,9,16])
#plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel('time')
plt.ylabel('distance')
plt.show()

# %% [markdown]
# ## Problem 3
# ### Problem statement
# Plotting 2D graphs using Matplotlib

# %%
import numpy as np
t=np.arange(0.0, 2.0,0.1)
v=1+np.sin(2*np.pi*t)
plt.xlabel('Time')
plt.ylabel('voltage')
plt.grid(True)
plt.plot(t,v)
plt.savefig('figures/time-voltage.png')
plt.show()

# %% [markdown]
# ## Problem 4
# ### Problem statement
# Plot a line graph on income vs. year for the state of california using Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('DataFiles/Income.csv')
y=df.values[4]
x=df.columns
x
y
years=[]
for i in range(2,len(x)):
    years.append(x[i])
years
income=[]
for i in range(2,len(y)):
    income.append(y[i])
income
plt.xlabel('year')
plt.ylabel('income')
plt.plot(years,income)
plt.grid(True)
plt.show()
plt.title('Income of California')
plt.savefig('figures/californialine.png')

#To draw a bar plot for the same instead of line graph
width = 1/1.5
plt.bar(years,income,width,color='gray')
plt.savefig('figures/californiabar.png')

# %% [markdown]
# ## Problem 4
# ### Problem statement
# BAR PLOT

# %%
plt.width = 1/3
plt.bar(years,income,width,color='turquoise')
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ## Problem 5
# ### Problem statement
# SCATTER PLOT for 50 random numbers

# %%
import numpy as np
n=50
x=np.random.rand(n)#Generate 50 random numbers
y=np.random.rand(n)#Generate 50 random numbers
colorlist=np.random.rand(n)#generate 50 random color values
arealist=np.pi*(15* np.random.rand(50))**2
plt.scatter(x,y,c=colorlist,s=arealist,alpha=1)
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ## Problem 6
# ### Problem statement
# HISTOGRAM
